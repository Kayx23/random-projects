# %% [markdown]
# ### Watson STT
#
# [Demo](https://speech-to-text-demo.ng.bluemix.net/?_ga=2.217141713.693030876.1609788968-299385472.1609788968&cm_mc_uid=14191683397816047653786&cm_mc_sid_50200000=19705671609796523033)
#
# [API Docs](https://cloud.ibm.com/apidocs/speech-to-text?code=python#recognize)
#
# [Github](https://github.com/watson-developer-cloud/python-sdk/blob/master/examples/speech_to_text_v1.py)

# %%
# authentication

import json
from ibm_watson import SpeechToTextV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

with open('key.json') as f:
    cred = json.load(f)

authenticator = IAMAuthenticator(cred['apikey'])
STT = SpeechToTextV1(authenticator=authenticator)

STT.set_service_url(cred['url'])

# %% [markdown]
# ### Small test

# %%
# get model
model = STT.get_model('en-US_BroadbandModel').get_result()
print(json.dumps(model, indent=4))
# Out:
# {
#     "name": "en-US_BroadbandModel",
#     "rate": 16000,
#     "language": "en-US",
#     "description": "US English broadband model.",
#     "supported_features": {
#         "custom_language_model": true,
#         "speaker_labels": true
#     },
#     "url": "https://api.us-south.speech-to-text.watson.cloud.ibm.com/instances/4021736b-f05b-49c8-b274-bae949b55613/v1/models/en-US_BroadbandModel"
# }

# %%
# speech recognition

with open('audio/test.mp3','rb') as audio_file:
    STT_result = STT.recognize(
        audio=audio_file,
        content_type='audio/mp3',
        word_alternatives_threshold=0.9,
        keywords=['she','related','him'],
        keywords_threshold=0.5
    ).get_result()
print(json.dumps(STT_result, indent=2))
# Out:
# {
#   "result_index": 0,
#   "results": [
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "she is related to him ",
#           "confidence": 0.96
#         }
#       ],
#       "word_alternatives": [
#         {
#           "start_time": 0.07,
#           "end_time": 0.37,
#           "alternatives": [
#             {
#               "word": "she",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 0.37,
#           "end_time": 0.55,
#           "alternatives": [
#             {
#               "word": "is",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 0.55,
#           "end_time": 1.13,
#           "alternatives": [
#             {
#               "word": "related",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 1.13,
#           "end_time": 1.28,
#           "alternatives": [
#             {
#               "word": "to",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 1.28,
#           "end_time": 1.65,
#           "alternatives": [
#             {
#               "word": "him",
#               "confidence": 0.95
#             }
#           ]
#         }
#       ],
#       "keywords_result": {
#         "she": [
#           {
#             "start_time": 0.07,
#             "end_time": 0.37,
#             "confidence": 0.99,
#             "normalized_text": "she"
#           }
#         ],
#         "related": [
#           {
#             "start_time": 0.55,
#             "end_time": 1.12,
#             "confidence": 0.99,
#             "normalized_text": "related"
#           }
#         ],
#         "him": [
#           {
#             "start_time": 1.28,
#             "end_time": 1.65,
#             "confidence": 0.95,
#             "normalized_text": "him"
#           }
#         ]
#       }
#     }
#   ]
# }

# %% [markdown]
# ### cut audio based on time stamp

# %%
from pydub import AudioSegment

# %%
sound = AudioSegment.from_mp3("audio/covid.mp3")

# %%
print("The audio is {0:.2f} minutes.".format(len(sound)/1000/60))
# Out:
# The audio is 1.95 minutes.

# %%
# speech recognition

# keywords=['Health Canada','their own']

# Dr. Tam
keywords=['I think the company','not plentiful']

with open('audio/covid.mp3','rb') as audio_file:
    STT_result = STT.recognize(
        audio=audio_file,
        content_type='audio/mp3',
        word_alternatives_threshold=0.9,
        keywords=keywords,
        keywords_threshold=0.5
    ).get_result()
print(json.dumps(STT_result, indent=2))
# Out:
# {
#   "result_index": 0,
#   "results": [
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "Renda severe won't protect anyone from covert nineteen but it can speed up a sick patients recovery time ",
#           "confidence": 0.81
#         }
#       ],
#       "word_alternatives": [
#         {
#           "start_time": 2.16,
#           "end_time": 2.66,
#           "alternatives": [
#             {
#               "word": "anyone",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 2.66,
#           "end_time": 2.87,
#           "alternatives": [
#             {
#               "word": "from",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 3.28,
#           "end_time": 3.89,
#           "alternatives": [
#             {
#               "word": "nineteen",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 3.89,
#           "end_time": 4.06,
#           "alternatives": [
#             {
#               "word": "but",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 4.06,
#           "end_time": 4.17,
#           "alternatives": [
#             {
#               "word": "it",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 4.17,
#           "end_time": 4.53,
#           "alternatives": [
#             {
#               "word": "can",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 4.53,
#           "end_time": 4.91,
#           "alternatives": [
#             {
#               "word": "speed",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 4.91,
#           "end_time": 5.11,
#           "alternatives": [
#             {
#               "word": "up",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 5.54,
#           "end_time": 5.98,
#           "alternatives": [
#             {
#               "word": "patients",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 5.98,
#           "end_time": 6.58,
#           "alternatives": [
#             {
#               "word": "recovery",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 6.58,
#           "end_time": 7.03,
#           "alternatives": [
#             {
#               "word": "time",
#               "confidence": 0.92
#             }
#           ]
#         }
#       ],
#       "keywords_result": {}
#     },
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "health Canada says doctors can now give it to any severely ill patients who can no longer breathe on their own I do think this drug will act against coded and grouped outcomes Canadian clinical trials testing the drug are still ongoing but health Canada says it's reviewed existing data on red dust of your safety efficacy and quality and decided the drug's benefits outweigh its risks for certain patients they'll be ongoing monitoring of the drug in terms of its effectiveness and safety as well Randazza beer was originally any bowler treatment it was not to block the virus from making copies of itself inside our cells unfortunately it didn't work the virus kept spreading but when Kobe nineteen patients were injected with the same drug a large American study found on average it reduced hospital stays from fifteen days to eleven ",
#           "confidence": 0.87
#         }
#       ],
#       "word_alternatives": [
#         {
#           "start_time": 8.15,
#           "end_time": 8.4,
#           "alternatives": [
#             {
#               "word": "health",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 8.4,
#           "end_time": 8.79,
#           "alternatives": [
#             {
#               "word": "Canada",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 8.79,
#           "end_time": 9.13,
#           "alternatives": [
#             {
#               "word": "says",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 9.13,
#           "end_time": 9.7,
#           "alternatives": [
#             {
#               "word": "doctors",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 9.7,
#           "end_time": 9.85,
#           "alternatives": [
#             {
#               "word": "can",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 9.85,
#           "end_time": 10.02,
#           "alternatives": [
#             {
#               "word": "now",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 10.02,
#           "end_time": 10.25,
#           "alternatives": [
#             {
#               "word": "give",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 10.25,
#           "end_time": 10.36,
#           "alternatives": [
#             {
#               "word": "it",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 10.36,
#           "end_time": 10.57,
#           "alternatives": [
#             {
#               "word": "to",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 10.63,
#           "end_time": 11.0,
#           "alternatives": [
#             {
#               "word": "any",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 11.0,
#           "end_time": 11.7,
#           "alternatives": [
#             {
#               "word": "severely",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 11.7,
#           "end_time": 11.92,
#           "alternatives": [
#             {
#               "word": "ill",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 11.92,
#           "end_time": 12.47,
#           "alternatives": [
#             {
#               "word": "patients",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 12.71,
#           "end_time": 12.85,
#           "alternatives": [
#             {
#               "word": "who",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 12.85,
#           "end_time": 13.02,
#           "alternatives": [
#             {
#               "word": "can",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 13.02,
#           "end_time": 13.22,
#           "alternatives": [
#             {
#               "word": "no",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 13.22,
#           "end_time": 13.6,
#           "alternatives": [
#             {
#               "word": "longer",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 13.6,
#           "end_time": 14.1,
#           "alternatives": [
#             {
#               "word": "breathe",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 14.1,
#           "end_time": 14.24,
#           "alternatives": [
#             {
#               "word": "on",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 14.24,
#           "end_time": 14.4,
#           "alternatives": [
#             {
#               "word": "their",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 14.4,
#           "end_time": 14.8,
#           "alternatives": [
#             {
#               "word": "own",
#               "confidence": 0.9
#             }
#           ]
#         },
#         {
#           "start_time": 14.88,
#           "end_time": 14.97,
#           "alternatives": [
#             {
#               "word": "I",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 14.97,
#           "end_time": 15.16,
#           "alternatives": [
#             {
#               "word": "do",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 15.16,
#           "end_time": 15.42,
#           "alternatives": [
#             {
#               "word": "think",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 15.42,
#           "end_time": 15.6,
#           "alternatives": [
#             {
#               "word": "this",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 17.23,
#           "end_time": 17.62,
#           "alternatives": [
#             {
#               "word": "against",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 19.83,
#           "end_time": 20.36,
#           "alternatives": [
#             {
#               "word": "Canadian",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 20.36,
#           "end_time": 20.73,
#           "alternatives": [
#             {
#               "word": "clinical",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 20.73,
#           "end_time": 21.22,
#           "alternatives": [
#             {
#               "word": "trials",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 21.22,
#           "end_time": 21.64,
#           "alternatives": [
#             {
#               "word": "testing",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 21.64,
#           "end_time": 21.74,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 21.74,
#           "end_time": 22.11,
#           "alternatives": [
#             {
#               "word": "drug",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 22.11,
#           "end_time": 22.32,
#           "alternatives": [
#             {
#               "word": "are",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 22.32,
#           "end_time": 22.64,
#           "alternatives": [
#             {
#               "word": "still",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 23.34,
#           "end_time": 23.47,
#           "alternatives": [
#             {
#               "word": "but",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 23.47,
#           "end_time": 23.68,
#           "alternatives": [
#             {
#               "word": "health",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 23.68,
#           "end_time": 24.06,
#           "alternatives": [
#             {
#               "word": "Canada",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 24.06,
#           "end_time": 24.42,
#           "alternatives": [
#             {
#               "word": "says",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 25.25,
#           "end_time": 25.92,
#           "alternatives": [
#             {
#               "word": "existing",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 25.92,
#           "end_time": 26.32,
#           "alternatives": [
#             {
#               "word": "data",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 26.35,
#           "end_time": 26.53,
#           "alternatives": [
#             {
#               "word": "on",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 27.25,
#           "end_time": 27.79,
#           "alternatives": [
#             {
#               "word": "safety",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 27.79,
#           "end_time": 28.48,
#           "alternatives": [
#             {
#               "word": "efficacy",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 28.51,
#           "end_time": 28.73,
#           "alternatives": [
#             {
#               "word": "and",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 28.73,
#           "end_time": 29.35,
#           "alternatives": [
#             {
#               "word": "quality",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 29.52,
#           "end_time": 29.67,
#           "alternatives": [
#             {
#               "word": "and",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 29.67,
#           "end_time": 30.33,
#           "alternatives": [
#             {
#               "word": "decided",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 30.5,
#           "end_time": 30.63,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 32.13,
#           "end_time": 32.34,
#           "alternatives": [
#             {
#               "word": "its",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 32.34,
#           "end_time": 32.9,
#           "alternatives": [
#             {
#               "word": "risks",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 32.95,
#           "end_time": 33.12,
#           "alternatives": [
#             {
#               "word": "for",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 33.12,
#           "end_time": 33.46,
#           "alternatives": [
#             {
#               "word": "certain",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 35.51,
#           "end_time": 36.01,
#           "alternatives": [
#             {
#               "word": "of",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 36.04,
#           "end_time": 36.14,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 36.14,
#           "end_time": 36.49,
#           "alternatives": [
#             {
#               "word": "drug",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 36.49,
#           "end_time": 36.61,
#           "alternatives": [
#             {
#               "word": "in",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 36.61,
#           "end_time": 37.02,
#           "alternatives": [
#             {
#               "word": "terms",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 37.02,
#           "end_time": 37.15,
#           "alternatives": [
#             {
#               "word": "of",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 37.31,
#           "end_time": 37.96,
#           "alternatives": [
#             {
#               "word": "effectiveness",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 37.96,
#           "end_time": 38.22,
#           "alternatives": [
#             {
#               "word": "and",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 38.22,
#           "end_time": 38.69,
#           "alternatives": [
#             {
#               "word": "safety",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 38.69,
#           "end_time": 38.86,
#           "alternatives": [
#             {
#               "word": "as",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 38.86,
#           "end_time": 39.26,
#           "alternatives": [
#             {
#               "word": "well",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 40.57,
#           "end_time": 41.2,
#           "alternatives": [
#             {
#               "word": "originally",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 41.23,
#           "end_time": 41.43,
#           "alternatives": [
#             {
#               "word": "any",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 42.34,
#           "end_time": 42.47,
#           "alternatives": [
#             {
#               "word": "it",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 42.47,
#           "end_time": 42.59,
#           "alternatives": [
#             {
#               "word": "was",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 42.75,
#           "end_time": 42.83,
#           "alternatives": [
#             {
#               "word": "to",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 42.83,
#           "end_time": 43.2,
#           "alternatives": [
#             {
#               "word": "block",
#               "confidence": 0.9
#             }
#           ]
#         },
#         {
#           "start_time": 43.2,
#           "end_time": 43.3,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 43.3,
#           "end_time": 43.71,
#           "alternatives": [
#             {
#               "word": "virus",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 43.71,
#           "end_time": 43.9,
#           "alternatives": [
#             {
#               "word": "from",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 43.9,
#           "end_time": 44.21,
#           "alternatives": [
#             {
#               "word": "making",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 44.21,
#           "end_time": 44.65,
#           "alternatives": [
#             {
#               "word": "copies",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 44.65,
#           "end_time": 44.76,
#           "alternatives": [
#             {
#               "word": "of",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 44.76,
#           "end_time": 45.24,
#           "alternatives": [
#             {
#               "word": "itself",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 45.3,
#           "end_time": 45.85,
#           "alternatives": [
#             {
#               "word": "inside",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 46.78,
#           "end_time": 47.78,
#           "alternatives": [
#             {
#               "word": "unfortunately",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 47.82,
#           "end_time": 48.04,
#           "alternatives": [
#             {
#               "word": "it",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 48.04,
#           "end_time": 48.34,
#           "alternatives": [
#             {
#               "word": "didn't",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 48.34,
#           "end_time": 48.82,
#           "alternatives": [
#             {
#               "word": "work",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 48.99,
#           "end_time": 49.1,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 49.1,
#           "end_time": 49.56,
#           "alternatives": [
#             {
#               "word": "virus",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 49.56,
#           "end_time": 49.86,
#           "alternatives": [
#             {
#               "word": "kept",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 49.86,
#           "end_time": 50.49,
#           "alternatives": [
#             {
#               "word": "spreading",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 50.8,
#           "end_time": 50.98,
#           "alternatives": [
#             {
#               "word": "but",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 50.98,
#           "end_time": 51.13,
#           "alternatives": [
#             {
#               "word": "when",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 52.79,
#           "end_time": 53.31,
#           "alternatives": [
#             {
#               "word": "injected",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 53.31,
#           "end_time": 53.46,
#           "alternatives": [
#             {
#               "word": "with",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 53.46,
#           "end_time": 53.55,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 53.55,
#           "end_time": 53.9,
#           "alternatives": [
#             {
#               "word": "same",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 54.57,
#           "end_time": 54.71,
#           "alternatives": [
#             {
#               "word": "a",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 54.71,
#           "end_time": 55.09,
#           "alternatives": [
#             {
#               "word": "large",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 55.09,
#           "end_time": 55.58,
#           "alternatives": [
#             {
#               "word": "American",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 55.58,
#           "end_time": 55.93,
#           "alternatives": [
#             {
#               "word": "study",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 55.93,
#           "end_time": 56.31,
#           "alternatives": [
#             {
#               "word": "found",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 56.34,
#           "end_time": 56.6,
#           "alternatives": [
#             {
#               "word": "on",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 56.6,
#           "end_time": 57.18,
#           "alternatives": [
#             {
#               "word": "average",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 57.33,
#           "end_time": 57.51,
#           "alternatives": [
#             {
#               "word": "it",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 57.51,
#           "end_time": 57.97,
#           "alternatives": [
#             {
#               "word": "reduced",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 57.97,
#           "end_time": 58.48,
#           "alternatives": [
#             {
#               "word": "hospital",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 58.48,
#           "end_time": 58.89,
#           "alternatives": [
#             {
#               "word": "stays",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 58.89,
#           "end_time": 59.11,
#           "alternatives": [
#             {
#               "word": "from",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 59.11,
#           "end_time": 59.69,
#           "alternatives": [
#             {
#               "word": "fifteen",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 59.69,
#           "end_time": 60.14,
#           "alternatives": [
#             {
#               "word": "days",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 60.21,
#           "end_time": 60.37,
#           "alternatives": [
#             {
#               "word": "to",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 60.37,
#           "end_time": 60.96,
#           "alternatives": [
#             {
#               "word": "eleven",
#               "confidence": 0.93
#             }
#           ]
#         }
#       ],
#       "keywords_result": {}
#     },
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "doctors say they'll take any help they can get a lot of research is really substantial surgeon all ",
#           "confidence": 0.69
#         }
#       ],
#       "word_alternatives": [
#         {
#           "start_time": 63.18,
#           "end_time": 63.46,
#           "alternatives": [
#             {
#               "word": "any",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 63.46,
#           "end_time": 63.76,
#           "alternatives": [
#             {
#               "word": "help",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 63.76,
#           "end_time": 63.89,
#           "alternatives": [
#             {
#               "word": "they",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 63.89,
#           "end_time": 64.09,
#           "alternatives": [
#             {
#               "word": "can",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 64.09,
#           "end_time": 64.52,
#           "alternatives": [
#             {
#               "word": "get",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 64.69,
#           "end_time": 64.78,
#           "alternatives": [
#             {
#               "word": "a",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 64.78,
#           "end_time": 65.02,
#           "alternatives": [
#             {
#               "word": "lot",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 65.02,
#           "end_time": 65.08,
#           "alternatives": [
#             {
#               "word": "of",
#               "confidence": 0.9
#             }
#           ]
#         }
#       ],
#       "keywords_result": {}
#     },
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "like you have all your ",
#           "confidence": 0.88
#         }
#       ],
#       "word_alternatives": [
#         {
#           "start_time": 69.16,
#           "end_time": 69.35,
#           "alternatives": [
#             {
#               "word": "like",
#               "confidence": 0.92
#             }
#           ]
#         },
#         {
#           "start_time": 69.42,
#           "end_time": 69.62,
#           "alternatives": [
#             {
#               "word": "have",
#               "confidence": 0.92
#             }
#           ]
#         },
#         {
#           "start_time": 69.62,
#           "end_time": 69.81,
#           "alternatives": [
#             {
#               "word": "all",
#               "confidence": 0.93
#             }
#           ]
#         }
#       ],
#       "keywords_result": {}
#     },
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "your therapy is ready for deployment and yet there is no guarantee that it will be ready run test of your ease now approved for use in Canada but it's expensive and really hard to find the U. S. government has bought up almost the entire global supply I think the company will begin to accelerate its capacity but ",
#           "confidence": 0.89
#         }
#       ],
#       "word_alternatives": [
#         {
#           "start_time": 72.86,
#           "end_time": 73.61,
#           "alternatives": [
#             {
#               "word": "deployment",
#               "confidence": 0.9
#             }
#           ]
#         },
#         {
#           "start_time": 73.96,
#           "end_time": 74.16,
#           "alternatives": [
#             {
#               "word": "and",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 74.16,
#           "end_time": 74.42,
#           "alternatives": [
#             {
#               "word": "yet",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 74.67,
#           "end_time": 74.83,
#           "alternatives": [
#             {
#               "word": "no",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 74.83,
#           "end_time": 75.42,
#           "alternatives": [
#             {
#               "word": "guarantee",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 75.42,
#           "end_time": 75.56,
#           "alternatives": [
#             {
#               "word": "that",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 75.56,
#           "end_time": 75.67,
#           "alternatives": [
#             {
#               "word": "it",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 75.67,
#           "end_time": 75.93,
#           "alternatives": [
#             {
#               "word": "will",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 75.93,
#           "end_time": 76.12,
#           "alternatives": [
#             {
#               "word": "be",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 76.12,
#           "end_time": 76.55,
#           "alternatives": [
#             {
#               "word": "ready",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 78.27,
#           "end_time": 78.4,
#           "alternatives": [
#             {
#               "word": "for",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 78.4,
#           "end_time": 78.73,
#           "alternatives": [
#             {
#               "word": "use",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 78.73,
#           "end_time": 78.9,
#           "alternatives": [
#             {
#               "word": "in",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 78.9,
#           "end_time": 79.42,
#           "alternatives": [
#             {
#               "word": "Canada",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 79.56,
#           "end_time": 79.74,
#           "alternatives": [
#             {
#               "word": "but",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 79.74,
#           "end_time": 79.88,
#           "alternatives": [
#             {
#               "word": "it's",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 79.88,
#           "end_time": 80.62,
#           "alternatives": [
#             {
#               "word": "expensive",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 80.65,
#           "end_time": 80.96,
#           "alternatives": [
#             {
#               "word": "and",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 80.96,
#           "end_time": 81.25,
#           "alternatives": [
#             {
#               "word": "really",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 81.25,
#           "end_time": 81.54,
#           "alternatives": [
#             {
#               "word": "hard",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 81.54,
#           "end_time": 81.62,
#           "alternatives": [
#             {
#               "word": "to",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 81.62,
#           "end_time": 82.19,
#           "alternatives": [
#             {
#               "word": "find",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 82.35,
#           "end_time": 82.47,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 82.47,
#           "end_time": 82.58,
#           "alternatives": [
#             {
#               "word": "U.",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 82.58,
#           "end_time": 82.78,
#           "alternatives": [
#             {
#               "word": "S.",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 82.78,
#           "end_time": 83.25,
#           "alternatives": [
#             {
#               "word": "government",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 83.25,
#           "end_time": 83.41,
#           "alternatives": [
#             {
#               "word": "has",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 83.69,
#           "end_time": 83.96,
#           "alternatives": [
#             {
#               "word": "up",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 84.13,
#           "end_time": 84.48,
#           "alternatives": [
#             {
#               "word": "almost",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 84.48,
#           "end_time": 84.59,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 84.59,
#           "end_time": 85.2,
#           "alternatives": [
#             {
#               "word": "entire",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 85.2,
#           "end_time": 85.68,
#           "alternatives": [
#             {
#               "word": "global",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 85.68,
#           "end_time": 86.39,
#           "alternatives": [
#             {
#               "word": "supply",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 86.49,
#           "end_time": 86.61,
#           "alternatives": [
#             {
#               "word": "I",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 86.61,
#           "end_time": 86.85,
#           "alternatives": [
#             {
#               "word": "think",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 86.85,
#           "end_time": 86.93,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 86.93,
#           "end_time": 87.3,
#           "alternatives": [
#             {
#               "word": "company",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 87.3,
#           "end_time": 87.65,
#           "alternatives": [
#             {
#               "word": "will",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 87.65,
#           "end_time": 88.12,
#           "alternatives": [
#             {
#               "word": "begin",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 88.12,
#           "end_time": 88.5,
#           "alternatives": [
#             {
#               "word": "to",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 88.5,
#           "end_time": 89.3,
#           "alternatives": [
#             {
#               "word": "accelerate",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 89.44,
#           "end_time": 90.18,
#           "alternatives": [
#             {
#               "word": "capacity",
#               "confidence": 0.9
#             }
#           ]
#         },
#         {
#           "start_time": 90.18,
#           "end_time": 90.61,
#           "alternatives": [
#             {
#               "word": "but",
#               "confidence": 0.91
#             }
#           ]
#         }
#       ],
#       "keywords_result": {
#         "I think the company": [
#           {
#             "start_time": 86.49,
#             "end_time": 87.3,
#             "confidence": 0.98,
#             "normalized_text": "I think the company"
#           }
#         ]
#       }
#     },
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "the bottom line is that the supply is not plentiful in an email the drug maker said it expects to meet real time demand in Canada and around the world in October it's perhaps not the slam dunk we might have hoped for other treatments are in the works but with fall just around the corner the push for answers is relentless Christine Bayer AG CBC news Toronto ",
#           "confidence": 0.92
#         }
#       ],
#       "word_alternatives": [
#         {
#           "start_time": 91.42,
#           "end_time": 91.5,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 91.5,
#           "end_time": 91.83,
#           "alternatives": [
#             {
#               "word": "bottom",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 91.83,
#           "end_time": 92.14,
#           "alternatives": [
#             {
#               "word": "line",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 92.14,
#           "end_time": 92.44,
#           "alternatives": [
#             {
#               "word": "is",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 92.44,
#           "end_time": 92.81,
#           "alternatives": [
#             {
#               "word": "that",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 92.81,
#           "end_time": 92.92,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 92.92,
#           "end_time": 93.43,
#           "alternatives": [
#             {
#               "word": "supply",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 93.43,
#           "end_time": 93.67,
#           "alternatives": [
#             {
#               "word": "is",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 93.67,
#           "end_time": 93.99,
#           "alternatives": [
#             {
#               "word": "not",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 93.99,
#           "end_time": 94.58,
#           "alternatives": [
#             {
#               "word": "plentiful",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 95.27,
#           "end_time": 95.41,
#           "alternatives": [
#             {
#               "word": "in",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 95.41,
#           "end_time": 95.51,
#           "alternatives": [
#             {
#               "word": "an",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 95.51,
#           "end_time": 95.94,
#           "alternatives": [
#             {
#               "word": "email",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 95.94,
#           "end_time": 96.03,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 0.93
#             }
#           ]
#         },
#         {
#           "start_time": 96.03,
#           "end_time": 96.31,
#           "alternatives": [
#             {
#               "word": "drug",
#               "confidence": 0.91
#             }
#           ]
#         },
#         {
#           "start_time": 96.31,
#           "end_time": 96.62,
#           "alternatives": [
#             {
#               "word": "maker",
#               "confidence": 0.92
#             }
#           ]
#         },
#         {
#           "start_time": 96.62,
#           "end_time": 97.0,
#           "alternatives": [
#             {
#               "word": "said",
#               "confidence": 0.95
#             }
#           ]
#         },
#         {
#           "start_time": 97.05,
#           "end_time": 97.2,
#           "alternatives": [
#             {
#               "word": "it",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 97.2,
#           "end_time": 97.61,
#           "alternatives": [
#             {
#               "word": "expects",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 97.61,
#           "end_time": 97.72,
#           "alternatives": [
#             {
#               "word": "to",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 97.72,
#           "end_time": 98.02,
#           "alternatives": [
#             {
#               "word": "meet",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 98.02,
#           "end_time": 98.29,
#           "alternatives": [
#             {
#               "word": "real",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 98.29,
#           "end_time": 98.58,
#           "alternatives": [
#             {
#               "word": "time",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 98.58,
#           "end_time": 99.0,
#           "alternatives": [
#             {
#               "word": "demand",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 99.0,
#           "end_time": 99.13,
#           "alternatives": [
#             {
#               "word": "in",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 99.13,
#           "end_time": 99.68,
#           "alternatives": [
#             {
#               "word": "Canada",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 99.84,
#           "end_time": 99.98,
#           "alternatives": [
#             {
#               "word": "and",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 99.98,
#           "end_time": 100.34,
#           "alternatives": [
#             {
#               "word": "around",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 100.34,
#           "end_time": 100.41,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 100.41,
#           "end_time": 100.93,
#           "alternatives": [
#             {
#               "word": "world",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 100.96,
#           "end_time": 101.1,
#           "alternatives": [
#             {
#               "word": "in",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 101.1,
#           "end_time": 101.82,
#           "alternatives": [
#             {
#               "word": "October",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 102.85,
#           "end_time": 103.28,
#           "alternatives": [
#             {
#               "word": "perhaps",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 103.28,
#           "end_time": 103.62,
#           "alternatives": [
#             {
#               "word": "not",
#               "confidence": 0.9
#             }
#           ]
#         },
#         {
#           "start_time": 103.62,
#           "end_time": 103.72,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 103.72,
#           "end_time": 104.1,
#           "alternatives": [
#             {
#               "word": "slam",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 104.1,
#           "end_time": 104.4,
#           "alternatives": [
#             {
#               "word": "dunk",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 104.4,
#           "end_time": 104.51,
#           "alternatives": [
#             {
#               "word": "we",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 104.51,
#           "end_time": 104.7,
#           "alternatives": [
#             {
#               "word": "might",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 106.57,
#           "end_time": 107.06,
#           "alternatives": [
#             {
#               "word": "treatments",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 107.09,
#           "end_time": 107.41,
#           "alternatives": [
#             {
#               "word": "are",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 107.41,
#           "end_time": 107.52,
#           "alternatives": [
#             {
#               "word": "in",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 107.52,
#           "end_time": 107.61,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 107.61,
#           "end_time": 108.08,
#           "alternatives": [
#             {
#               "word": "works",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 108.08,
#           "end_time": 108.3,
#           "alternatives": [
#             {
#               "word": "but",
#               "confidence": 0.99
#             }
#           ]
#         },
#         {
#           "start_time": 108.3,
#           "end_time": 108.5,
#           "alternatives": [
#             {
#               "word": "with",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 108.5,
#           "end_time": 108.86,
#           "alternatives": [
#             {
#               "word": "fall",
#               "confidence": 0.94
#             }
#           ]
#         },
#         {
#           "start_time": 108.86,
#           "end_time": 109.22,
#           "alternatives": [
#             {
#               "word": "just",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 109.22,
#           "end_time": 109.56,
#           "alternatives": [
#             {
#               "word": "around",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 109.56,
#           "end_time": 109.63,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 109.63,
#           "end_time": 110.2,
#           "alternatives": [
#             {
#               "word": "corner",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 110.43,
#           "end_time": 110.54,
#           "alternatives": [
#             {
#               "word": "the",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 110.54,
#           "end_time": 110.91,
#           "alternatives": [
#             {
#               "word": "push",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 110.91,
#           "end_time": 111.1,
#           "alternatives": [
#             {
#               "word": "for",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 111.1,
#           "end_time": 111.73,
#           "alternatives": [
#             {
#               "word": "answers",
#               "confidence": 0.96
#             }
#           ]
#         },
#         {
#           "start_time": 112.02,
#           "end_time": 112.23,
#           "alternatives": [
#             {
#               "word": "is",
#               "confidence": 0.91
#             }
#           ]
#         }
#       ],
#       "keywords_result": {
#         "not plentiful": [
#           {
#             "start_time": 93.67,
#             "end_time": 94.58,
#             "confidence": 1.0,
#             "normalized_text": "not plentiful"
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
keywords_result = dict()

for result in STT_result['results']:
    keywords_result = {**keywords_result, **result['keywords_result']}  # merge dict

# %%
keywords_result
# Out:
# {'I think the company': [{'start_time': 86.49,
#    'end_time': 87.3,
#    'confidence': 0.98,
#    'normalized_text': 'I think the company'}],
#  'not plentiful': [{'start_time': 93.67,
#    'end_time': 94.58,
#    'confidence': 1.0,
#    'normalized_text': 'not plentiful'}]}

# %%
for keyword in keywords:
    
    print(keyword)
    print(keywords_result[keyword][0]['start_time'])
    print(keywords_result[keyword][0]['end_time'])
# Out:
# I think the company
# 86.49
# 87.3
# not plentiful
# 93.67
# 94.58

# %%
# check confidence level 

for keyword in keywords:
    
    if keyword in keywords_result: 
        if keywords_result[keyword][0]['confidence'] > 0.7:
            pass
    else:
        raise Exception("low confidence level")

# %%
# cutting and exporting audio

test = sound[86.49*1000:94.58*1000]
test.export("audio/drTam.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='audio/drTam.mp3'>
